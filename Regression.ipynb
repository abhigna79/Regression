# %% [markdown]
# #Regression

# %% [markdown]
# 1. What is Simple Linear Regression?
#    - Simple Linear Regression is a statistical method used to model the relationship between two variables:
#
#    - One independent variable (X) – the predictor or input
#
#    - One dependent variable (Y) – the response or output
#
# 2. What are the key assumptions of Simple Linear Regression?
#    - Simple Linear Regression relies on several key assumptions to ensure the validity of its results.  they are:
#    - Linearity
#    -  Independence of Errors
#    -  Homoscedasticity
#    - Normality of Errors
#    - No Perfect Multicollinearity
#
# 3.  What does the coefficient m represent in the equation Y=mX+c?
#     -   The coefficient
# 𝑚 represents the slope of the line.
#
#    - It shows the rate of change of
# 𝑌 with respect to
# 𝑋.
#    - Specifically, it tells you how much Y changes for every 1 unit increase in X.
#
# 4. What does the intercept c represent in the equation Y=mX+c?
#    - The intercept
# 𝑐 represents:
#    - The value of
# 𝑌 when X=0.
#
# 5. How do we calculate the slope m in Simple Linear Regression?
#    - To calculate the slope
# 𝑚 in Simple Linear Regression, we use a formula based on the data points you have for X (independent variable) and Y (dependent variable).
#
#   - Calculate the mean of X and Y
#   - Plug values into the slope formula
#   - Use the slope to build the equation:
# 𝑌
# =
# 𝑚X+c
#
# 6. What is the purpose of the least squares method in Simple Linear Regression?
#    - To find the best-fitting line through the data by minimizing the sum of the squared differences between the actual data points and the predicted values from the line.
#
# 7.  How is the coefficient of determination (R²) interpreted in Simple Linear Regression?
#     - R² (R-squared) is one of the most important metrics in regression analysis!
#     - R² measures how well the regression line fits the data.
#     - it tells you how much of the variation in the dependent variable (Y) is explained by the independent variable (X) in your model.
#
# 8. What is Multiple Linear Regression?
#    - Multiple Linear Regression (MLR) is a statistical technique that models the relationship between one dependent variable (Y) and two or more independent variables (X₁, X₂, X₃, ... Xₙ).
#
# 9. What is the main difference between Simple and Multiple Linear Regression?
#    - Simple linear regression:
#    - Only one predictor (X)
#    - When a single factor predicts Y well
#    - Simpler and easier to interpret
#
#    -  Multiple Linear Regression:
#    - Two or more predictors (X₁, X₂, ..., Xₙ)
#    - When multiple factors influence Y
#    - More complex but can give better accuracy
#
# 10. What are the key assumptions of Multiple Linear Regression?
#     - The key assumptions of Multiple Linear Regression:
#     - Linearity
#     -  Independence of Errors
#     - Homoscedasticity
#     - Normality of Errors
#     -  No Multicollinearity
#     - No Perfectly Linear Relationships
#
# 11.  What is heteroscedasticity, and how does it affect the results of a Multiple Linear Regression model?
#     - What is Heteroscedasticity?
#     - Heteroscedasticity refers to a situation where the variance of the residuals (errors) in a regression model is not constant across all levels of the independent variables.
#
#     - How Does Heteroscedasticity Affect a Multiple Linear Regression Model?
#     - Bias in Coefficient Estimates
#     - Incorrect Inferences
#     - Confidence Intervals
#     - Inefficient Predictions
#
# 12. How can you improve a Multiple Linear Regression model with high multicollinearity?
#    - Remove Highly Correlated Variables
#    - Combine Correlated Variables (Feature Engineering)
#    - Use Ridge or Lasso Regression (Regularization Techniques)
#    -  Center the Variables (Mean-Centering)
#    -  Increase the Sample Size
#    - Examine and Correct for Collinearity Using Variance Inflation Factor (VIF)
#    - Transform Variables
#
# 13. What are some common techniques for transforming categorical variables for use in regression models?
#    - One-Hot Encoding
#    - Label Encoding
#    -  Binary Encoding
#    - Target Encoding (Mean Encoding)
#    - Frequency (Count) Encoding
#    - Hashing
#
# 14. What is the role of interaction terms in Multiple Linear Regression?
#     - In Multiple Linear Regression (MLR), interaction terms are used to model the effect that two or more independent variables (predictors) have on the dependent variable together (rather than independently). Interaction terms capture combined effects of variables that aren't simply additive — meaning the effect of one variable on the outcome depends on the level of another variable.
#
# 15.  How can the interpretation of intercept differ between Simple and Multiple Linear Regression?
#     - The interpretation of the intercept in Simple Linear Regression (SLR) and Multiple Linear Regression (MLR) can differ significantly due to the number of predictors (independent variables) involved in the model.
#
# 16. What is the significance of the slope in regression analysis, and how does it affect predictions?
#     - In regression analysis, the slope represents the rate of change of the dependent variable (
# 𝑌) with respect to a one-unit change in the independent variable . It essentially describes how much
# 𝑌 will change for each unit increase in X. The slope is a crucial component of the regression model, and its interpretation can provide valuable insights into the strength and direction of the relationship between the variables.
#
#    - How Does the Slope Affect Predictions?
#    - In Simple Linear Regression
#    - In Multiple Linear Regression
#
# 17.  How does the intercept in a regression model provide context for the relationship between variables?
#     - In a regression model, the intercept — often denoted as
# 𝛽
# 0
# ​
#   — represents the expected value of the dependent variable when all independent variables are equal to zero. While the intercept may not always have a meaningful real-world interpretation, it plays a crucial contextual and mathematical role in the regression equation.
#
# 18. What are the limitations of using R² as a sole measure of model performance?
#     - R
# 2
#   is a popular metric in regression analysis, using it as the sole measure of model performance comes with several important limitations
#   - Does Not Indicate Causality
#   - Sensitive to Overfitting
#   - Does Not Reflect Model Accuracy
#   -  Misleading for Non-Linear Relationships
#   -  Affected by Outliers
#   - Comparisons Between Models
#
# 19. How would you interpret a large standard error for a regression coefficient?
#     - A large standard error for a regression coefficient suggests that there is a lot of uncertainty or instability in the estimate of that coefficient.
#
# 20. How can heteroscedasticity be identified in residual plots, and why is it important to address it?
#     -  How to Identify Heteroscedasticity in Residual Plots
#    -  Use a Residuals vs. Fitted Values Plot
#    - Plot Residuals vs. Each Predictor
#    - Statistical Tests
#
#    -  Why Is It Important to Address Heteroscedasticity?
#    - Makes Standard Errors Unreliable
#    - Violates OLS Assumptions
#    - Can Affect Model Interpretation
#
# 21. What does it mean if a Multiple Linear Regression model has a high R² but low adjusted R²?
#     - If a Multiple Linear Regression model has a high R² but a low Adjusted R², it's a red flag that the model may include irrelevant or non-contributing predictors.
#
# 22. Why is it important to scale variables in Multiple Linear Regression?
#     - Scaling variables in Multiple Linear Regression is important for several practical and interpretive reasons, especially when your model involves variables with different units or magnitudes.
#     - Why Scaling important in Multiple Linear Regression:
#     - Improves Interpretability of Coefficients
#     -  Helps with Regularization
#     - Avoids Numerical Instability
#     - Useful When Interactions Are Included
#
# 23. What is polynomial regression?
#     - Polynomial regression is a type of regression analysis where the relationship between the independent variable
# 𝑋 and the dependent variable
# 𝑌 is modeled as an nth-degree polynomial.
#
# 24. How does polynomial regression differ from linear regression?
#     - Linear Regression:
#     - Models a straight-line relationship between X and Y
#     - Polynomial Regression:
#     - Models a curved or non-linear relationship between X and Y.
#
# 25. When is polynomial regression used?
#     - Polynomial regression is used when the relationship between the independent variable(s) and the dependent variable is non-linear, but can still be modeled using a smooth curve. It extends linear regression by fitting a polynomial equation to the data.
#     -  When to Use Polynomial Regression:
#     -  When the Data Shows a Curved Trend
#     - When You Suspect a Non-Linear Relationship
#     -  When You Want a Flexible Model Without Splines or Trees
#     - In Physical or Natural Phenomena
#
# 26. What is the general equation for polynomial regression?
#     - The general equation for polynomial regression is
#     - Y: Dependent (response) variable
#     - X: Independent (predictor) variable
#     -
# β
# 0
# ​
#  : Intercept (constant term)
#     - 𝛽
# 1
# ,
# 𝛽
# 2
# ,
# .
# .
# .
# ,
# 𝛽
# 𝑛
# ​
#  : Coefficients for each power of
# x
#    - X
# 1
#  ,X
# 2
#  ,X
# 3
#  ,...,X
# n
#  : The powers of
# 𝑋
#     - ε: Error term, representing the difference between the observed and predicted valuesthat correspond to the polynomial terms
#
# 27. Can polynomial regression be applied to multiple variables?
#     - Yes, polynomial regression can indeed be applied to multiple variables. This is called multivariable polynomial regression or multiple polynomial regression. The general concept is similar to polynomial regression, but instead of just one predictor variable
# 𝑋, you can have multiple predictors (independent variables) raised to different powers.
#
# 28. What are the limitations of polynomial regression?
#     - Overfitting
#     -  Poor Extrapolation
#     - Multicollinearity
#     - Interpretation Challenges
#     - Sensitive to Outliers
#     -  Complexity and Computation
#     - Non-Uniform Behavior Across the Range of X
#     - Lack of Flexibility with Complex Data Patterns
#
# 29. What methods can be used to evaluate model fit when selecting the degree of a polynomial?
#     - When selecting the degree of a polynomial in polynomial regression, it's crucial to evaluate the model fit to ensure the best trade-off between model complexity and generalization (i.e., avoiding overfitting)
#     -  Cross-Validation
#     - Adjusted R²
#     - Mean Squared Error (MSE) or Root Mean Squared Error (RMSE)
#     - AIC (Akaike Information Criterion) and BIC (Bayesian Information Criterion)
#     - Learning Curves
#     - Visual Inspection of Residuals
#     - Holdout Set (Test Set Evaluation)
#
# 30. Why is visualization important in polynomial regression?
#     - Visualization plays a crucial role in polynomial regression because it helps you better understand the data, the model’s fit, and the relationship between the variables
#     - Understanding the Data's Pattern
#     - Choosing the Right Polynomial Degree
#     - Model Evaluation and Diagnostics
#     - Interpreting Complex Relationships
#     - Detecting Model Misspecification
#     -  Improving Communication and Presentation
#
# 31. How is polynomial regression implemented in Python?
#     - To implement polynomial regression in Python, we can use scikit-learn and matplotlib libraries for model fitting and visualization, respectively.
#     - Import Libraries
#     - Generate or Load Data
#     -  Visualize the Data
#     - Polynomial Feature Transformation
#     - Fit the Polynomial Regression Model
#     - Make Predictions
#     - Visualize the Polynomial Regression Fit
#     - EXAMPLE

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# Step 1: Generate synthetic data
np.random.seed(0)
X = np.random.rand(100, 1) * 10  # Random X values between 0 and 10
y = 3 * X**2 + 2 * X + 5 + np.random.randn(100, 1) * 10  # Quadratic relationship with noise

# Step 2: Visualize the data
plt.scatter(X, y, color='blue', label='Data points')
plt.xlabel('X')
plt.ylabel('y')
plt.title('Scatter Plot of Data')
plt.show()

# Step 3: Polynomial Feature Transformation
degree = 2  # Degree of the polynomial (e.g., quadratic)
poly = PolynomialFeatures(degree=degree)
X_poly = poly.fit_transform(X)

# Step 4: Fit Polynomial Regression Model
model = LinearRegression()
model.fit(X_poly, y)

# Step 5: Make Predictions
y_pred = model.predict(X_poly)

# Step 6: Visualize the Polynomial Fit
X_grid = np.arange(min(X), max(X), 0.1)  # Smooth curve
X_grid = X_grid.reshape((len(X_grid), 1))
X_grid_poly = poly.transform(X_grid)
y_grid_pred = model.predict(X_grid_poly)

# Plotting
plt.scatter(X, y, color='blue', label='Data points')
plt.plot(X_grid, y_grid_pred, color='red', label=f'Polynomial fit (degree {degree})')
plt.xlabel('X')
plt.ylabel('y')
plt.title('Polynomial Regression')
plt.legend()
plt.show()
# Out:
# <ipython-input-1-5ae4f1762a2d>:31: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   X_grid = np.arange(min(X), max(X), 0.1)  # Smooth curve
